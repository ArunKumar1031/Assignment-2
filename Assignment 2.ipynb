# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

image = img.imread("https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/acb8f470-593f-4656-a0b4-1c19edd0eed3/d7lcxee-aeacc7b5-69de-4d07-95a2-8dde067d46ef.png/v1/fill/w_1024,h_733,q_75,strp/tiger_png_by_dagusan-d7lcxee.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..-fH5lsUGwM8sVA-MQTugSB6ESXNBCeeM4nK-Kag5JAc")
plt.imshow(image)
plt.show()
# Out:
# C:\Users\U1138638\AppData\Local\Temp\ipykernel_12268\1770860672.py:4: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("Butterfly.jpg")
imgplot = plt.imshow(image)
plt.show()
